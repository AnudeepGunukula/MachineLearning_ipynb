# %%
import numpy as np

# %%
def gradesc(x,y):
     m,b=0,0
     iter=10000
     learn=0.08
     n=len(x)
     min=100000000
     for i in range(iter):
         y_pred=m*x+b
         cost=(1/n)*sum([err*err for err in (y-y_pred)])
         dm=-(2/n)*sum(x*(y-y_pred))
         db=-(2/n)*sum(y-y_pred)
         m=m-learn*dm
         b=b-learn*db
         print('dm {},db {}, slope {}, intercept {}, cost {} ,iteration {}'.format(dm,db,m,b,cost,i))
         if cost<min:
              min=cost
         if cost==7.730836871165916e-30:
           li.append([dm,db,m,b,cost,i])
     print(min)
     print(li)
li=[]
x=[1,2,3,4,5]
y=[5,7,9,11,13]
x=np.array(x)
y=np.array(y)
gradesc(x,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# dm -1.5276668818842153e-14,db -6.039613253960852e-15, slope 2.000000000000002, intercept 2.999999999999995, cost 1.0255191767873153e-29 ,iteration 5003
# dm 1.7408297026122456e-14,db 3.197442310920451e-15, slope 2.000000000000001, intercept 2.9999999999999947, cost 1.0255191767873153e-29 ,iteration 5004
# dm -1.5276668818842153e-14,db -6.039613253960852e-15, slope 2.000000000000002, intercept 2.999999999999995, cost 1.0255191767873153e-29 ,iteration 5005
# dm 1.7408297026122456e-14,db 3.197442310920451e-15, slope 2.000000000000001, intercept 2.9999999999999947, cost 1.0255191767873153e-29 ,iteration 5006
# dm -1.5276668818842153e-14,db -6.039613253960852e-15, slope 2.000000000000002, intercept 2.999999999999995, cost 1.0255191767873153e-29 ,iteration 5007
# dm 1.7408297026122456e-14,db 3.197442310920451e-15, slope 2.000000000000001, intercept 2.9999999999999947, cost 1.0255191767873153e-29 ,iteration 5008
# ...
