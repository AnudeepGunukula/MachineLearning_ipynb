# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/california_housing_train.csv')
df=df.head(10)
df[1:8]
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 1    -114.47     34.40  ...         1.8200             80100.0
# 2    -114.56     33.69  ...         1.6509             85700.0
# 3    -114.57     33.64  ...         3.1917             73400.0
# 4    -114.57     33.57  ...         1.9250             65500.0
# 5    -114.58     33.63  ...         3.3438             74000.0
# 6    -114.58     33.61  ...         2.6768             82400.0
# 7    -114.59     34.83  ...         1.7083             48500.0
#
# [7 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.latitude
# Out:
# 0    34.19
# 1    34.40
# 2    33.69
# 3    33.64
# 4    33.57
# 5    33.63
# 6    33.61
# 7    34.83
# 8    33.61
# 9    34.83
# Name: latitude, dtype: float64

# %%
df['population']
# Out:
# 0    1015.0
# 1    1129.0
# 2     333.0
# 3     515.0
# 4     624.0
# 5     671.0
# 6    1841.0
# 7     375.0
# 8    3134.0
# 9     787.0
# Name: population, dtype: float64

# %%
df[['population','latitude']]                    #df.fillna(0) for Nan values refilling with 0
# Out:
#    population  latitude
# 0      1015.0     34.19
# 1      1129.0     34.40
# 2       333.0     33.69
# 3       515.0     33.64
# 4       624.0     33.57
# 5       671.0     33.63
# 6      1841.0     33.61
# 7       375.0     34.83
# 8      3134.0     33.61
# 9       787.0     34.83

# %%
df[['households','population']].describe()
# Out:
#         households   population
# count    10.000000    10.000000
# mean    389.700000  1042.400000
# std     283.480766   858.024242
# min     117.000000   333.000000
# 25%     229.250000   542.250000
# 50%     266.500000   729.000000
# 75%     469.750000  1100.500000
# max    1056.000000  3134.000000

# %%
df[['longitude','population']][df['population']>1000]

#df column selecting upto here ||| then the condition of filtering
# Out:
#    longitude  population
# 0    -114.31      1015.0
# 1    -114.47      1129.0
# 6    -114.58      1841.0
# 8    -114.59      3134.0

# %%
ndf=df.set_index('total_rooms')
display(ndf)
ndf.loc[7650.0]                     #selecting a row by setting its attribute as index and calling the loc with the value
# Out:
#              longitude  latitude  ...  median_income  median_house_value
# total_rooms                       ...
# 5612.0         -114.31     34.19  ...         1.4936             66900.0
# 7650.0         -114.47     34.40  ...         1.8200             80100.0
# 720.0          -114.56     33.69  ...         1.6509             85700.0
# 1501.0         -114.57     33.64  ...         3.1917             73400.0
# 1454.0         -114.57     33.57  ...         1.9250             65500.0
# 1387.0         -114.58     33.63  ...         3.3438             74000.0
# 2907.0         -114.58     33.61  ...         2.6768             82400.0
# 812.0          -114.59     34.83  ...         1.7083             48500.0
# 4789.0         -114.59     33.61  ...         2.1782             58400.0
# 1497.0         -114.60     34.83  ...         2.1908             48100.0
#
# [10 rows x 8 columns]
# longitude              -114.47
# latitude                 34.40
# housing_median_age       19.00
# ...

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[4,9,100,20,8,60,5]
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.title('simple plot')
plt.plot(x,y,color='green',linewidth=5,linestyle='dotted')

# %%
plt.plot(x,y,'r*--')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

a=['google','amazon','flipkart','facebook']
revenue=[35,26,42,39]
xaxis=np.arange(len(a))
profit=[50,26,49,52]
plt.barh(xaxis+0.2,profit,label='profit')
plt.barh(a,revenue,label='revenue')
plt.legend()
